# %%
# Importando a biblioteca "boto3" para interagir com a AWS
import boto3

# %%
s3 = boto3.client('s3')

# %%
s3.create_bucket(Bucket='aline-hp-pb')
# Out:
# {'ResponseMetadata': {'RequestId': 'PR8E5VV58B2XGPFG',
#   'HostId': 's0QwyUSBmTQmCtZ+itUJBrbgpIhEZkH06DZ9TgvLOIn6vnKbE9P9ZbeLcfT3orwfw0nz64BwUS8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 's0QwyUSBmTQmCtZ+itUJBrbgpIhEZkH06DZ9TgvLOIn6vnKbE9P9ZbeLcfT3orwfw0nz64BwUS8=',
#    'x-amz-request-id': 'PR8E5VV58B2XGPFG',
#    'date': 'Mon, 22 Sep 2025 21:41:53 GMT',
#    'location': '/aline-hp-pb',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/aline-hp-pb'}
