# %%
# Importando a biblioteca "boto3" para interagir com a AWS
import boto3

# %%
s3 = boto3.client('s3')

# %%
s3.create_bucket(Bucket='aline-hp-pb')
# Out:
# {'ResponseMetadata': {'RequestId': 'WAVCSCG3DDNKBJBH',
#   'HostId': 'U+zWc/VqqjxM0UXKE1vpegpvD7/AFNOOyNYmvS6yOyQGthj07IIv7xRm2/ZJnTY5Fu6oq6tT+zM=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'U+zWc/VqqjxM0UXKE1vpegpvD7/AFNOOyNYmvS6yOyQGthj07IIv7xRm2/ZJnTY5Fu6oq6tT+zM=',
#    'x-amz-request-id': 'WAVCSCG3DDNKBJBH',
#    'date': 'Mon, 22 Sep 2025 23:07:29 GMT',
#    'location': '/aline-hp-pb',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/aline-hp-pb'}

# %%
bucket_name = 'aline-hp-pb'
arquivo_local = 'feminicidio_2023.csv'
nome_s3 = 'dados.csv'

s3.upload_file(arquivo_local, bucket_name, nome_s3)
