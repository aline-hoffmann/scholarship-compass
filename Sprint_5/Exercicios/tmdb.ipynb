# %%
import requests
import pandas as pd
from IPython.display import display

api_key = "4e9572f883f351f99ca1729dfa04e22e"
url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=pt-BR"

response = requests.get(url)
data = response.json()
filmes = []
for movie in data['results']:
    df = {'Titulo': movie['title'],
    'Data de lançamento': movie['release_date'],
    'Visão geral': movie['overview'],
    'Votos': movie['vote_count'],
    'Média de votos:': movie['vote_average']}

    filmes.append(df)

df = pd.DataFrame(filmes)
display(df)
# Out:
#                                    Titulo Data de lançamento  \
# 0                   Um Sonho de Liberdade         1994-09-23
# 1                       O Poderoso Chefão         1972-03-14
# 2             O Poderoso Chefão: Parte II         1974-12-20
# 3                    A Lista de Schindler         1993-12-15
# 4                12 Homens e uma Sentença         1957-04-10
# 5                     A Viagem de Chihiro         2001-07-20
# 6          Batman: O Cavaleiro das Trevas         2008-07-16
# 7               Dilwale vai levar a noiva         1995-10-20
# 8                  À Espera de um Milagre         1999-12-10
# 9                                Parasita         2019-05-30
# 10   O Senhor dos Anéis: O Retorno do Rei         2003-12-17
# 11       Pulp Fiction: Tempo de Violência         1994-09-10
# 12                             Your name.         2016-08-26
# 13                Três Homens em Conflito         1966-12-22
# 14  Forrest Gump: O Contador de Histórias         1994-06-23
# 15                           Interestelar         2014-11-05
# 16                   Os Bons Companheiros         1990-09-12
# 17                       Os Sete Samurais         1954-04-26
# 18                 O Túmulo dos Vagalumes         1988-04-16
# 19                          A Vida é Bela         1997-12-20
#
#                                           Visão geral  Votos  Média de votos:
# 0   Em 1946, Andy Dufresne, um banqueiro jovem e b...  28972            8.712
# 1   Em 1945, Don Corleone é o chefe de uma mafiosa...  21902            8.686
# 2   Após a máfia matar sua família, o jovem Vito f...  13235            8.571
# 3   O alemão Oskar Schindler viu na mão de obra ju...  16747            8.566
# 4   Um jovem porto-riquenho é acusado do brutal cr...   9437            8.549
# 5   Chihiro e seus pais estão se mudando para uma ...  17526            8.535
# 6   Após dois anos desde o surgimento do Batman, o...  34490            8.523
# 7   Raj e Simran são dois jovens indianos vivendo ...   4508            8.500
# 8   Milagres acontecem em lugares inesperados, mes...  18411            8.503
# 9   Toda a família de Ki-taek está desempregada, v...  19544            8.498
# 10  O confronto final entre as forças do bem e do ...  25505            8.489
# 11  Vincent Vega e Jules Winnfield são dois assass...  29135            8.500
# 12  Mitsuha é a filha do prefeito de uma pequena c...  12025            8.479
# 13  Durante o auge da Guerra Civil, um misterioso ...   9187            8.465
# 14  Quarenta anos da história dos Estados Unidos, ...  28694            8.465
# 15  As reservas naturais da Terra estão chegando a...  37972            8.461
# 16  A história real de Henry Hill, um garoto meio ...  13674            8.454
# 17  Um bando de bandidos aterroriza os habitantes ...   3996            8.452
# 18  O filme relata a história de dois irmãos, Seit...   6130            8.448
# 19  Durante a Segunda Guerra Mundial na Itália, o ...  13565            8.441
